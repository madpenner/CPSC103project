# %% [markdown]
# ## Your poster must:
#
# Give an overview of your project.
# + What problem are you solving? Where is the information from? Why is it interesting to you?
# + Explain how you used what you learned about systematic program design to solve the problem. What design choices did you have to make? Why did you make the choices that you made?
# + Describe how you solved the problem. Provide visuals if possible, and definitely provide the graph or chart(s) that your program created.
# + Discuss which part of the project was the most difficult for you and why
# + Provide examples of ways in which you could use your systematic programming design skills to solve problems in your chosen topic area in the future.

# %% [markdown]
# # problem:
# ## I wanted to know, out of Cropland, Grazing, Forest, Carbon, and Fish, which of these factors had the highest footprint in contribution to a given countries Total Ecological Footprint
# ### I used information from "2016 Global Ecological Footprint" , I took the data for each country name, theyre cropland footprint, grazing footprint, forest footprint, carbon footprint, and fish footprint.
# ### this is really interesting to me because global ecological footprint is a subject most people know about, however, most people don't know what its made up of or what makes it as high as it is. I decided to take a subset of the information and figure out which factor was the highest contributor because I thought it would be interesting to know what is making our Global footprint as high as it is.

# %% [markdown]
# # what I used:
# ### * lots of helper functions
# ### * helper functions within helper functions
# ### * for loops mixed with helper functions
# ### one of the biggest design choices I had to make was choosing what to when my largest values were tied. The easiest thing would have been just to return whichever value appeared in the list first, but that would have been inaccurate.
# ### I learned how return the highest value, or return two seperate values in the case that they were tied.
#
# ### design choice for including labels

# %% [markdown]
# # how I solved the problem:
# ### First: biggest footprint per country
# ### Second: list of all the biggest footprints
# ### Third: for each footprint, count how many times my list of footprints contained a footprint of that type
# ### Fourth: list with the numbers representing how many times a factor appears
# ### Fifth: plot the counts vs the names of the factors in a pie chart to visually represent which factor appears as the biggest contributer the most

# %% [markdown]
# ![Screen%20Shot%202019-11-22%20at%201.39.28%20PM.png](attachment:Screen%20Shot%202019-11-22%20at%201.39.28%20PM.png)
#
# ![Screen%20Shot%202019-11-22%20at%201.39.05%20PM.png](attachment:Screen%20Shot%202019-11-22%20at%201.39.05%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202019-11-21%20at%207.16.02%20PM.png](attachment:Screen%20Shot%202019-11-21%20at%207.16.02%20PM.png)

# %% [markdown]
# # The Most Difficult:
# ## the most difficult part was definitly returning two footprints if tied
# ### I didn't know if i should use a loop, or just if statements
# ### I didn't know how to compare two items in a list at once
# ### Everytime something worked for one set of tests, there was always a different test that didn't pass, the order of if statements was very important, and looking at one value at a time is very important for determing which item had the biggest value.
# ### assigning specific values for an item to compare with the rest of the items in the list was necessary for finding any values that were tied.

# %% [markdown]
# ![Screen%20Shot%202019-11-21%20at%207.30.35%20PM.png](attachment:Screen%20Shot%202019-11-21%20at%207.30.35%20PM.png)

# %% [markdown]
# # ways to use these skills:
# ### After designing this program, I feel like I could adequately design similar programs using new datasets for other problems like this.
# ### I also feel confident that I could do much more with this given dataset and program to find even more information within this topic. Originally, I wanted to return the relative footprint amounts for each country. I wanted to compare the size of the footprint agaisnt the size of the given country and its population to see how much its relative contribution is to all of the global total footprint. I belive that now that I have all of this, I could design that program that seemed way too hard a month ago.
